# %%
import pandas as pd
import numpy as np

# %%
list_1 = ['KJSIEIT', 'TSCOE', 'DBIT', 'RAIT']
print(list_1)
# Out:
# ['KJSIEIT', 'TSCOE', 'DBIT', 'RAIT']

# %%
df = pd.DataFrame(list_1)
df.head()
# Out:
#          0
# 0  KJSIEIT
# 1    TSCOE
# 2     DBIT
# 3     RAIT

# %%
colg_names = {"Name":['KJSIEIT', 'TSCOE', 'DBIT', 'RAIT'],
             "Location": ['Sion', 'Bandra', 'Kurla', 'Nerul']}
print(colg_names)
# Out:
# {'Name': ['KJSIEIT', 'TSCOE', 'DBIT', 'RAIT'], 'Location': ['Sion', 'Bandra', 'Kurla', 'Nerul']}

# %%
colg_df = pd.DataFrame(colg_names)
colg_df.head()
# Out:
#       Name Location
# 0  KJSIEIT     Sion
# 1    TSCOE   Bandra
# 2     DBIT    Kurla
# 3     RAIT    Nerul

# %%
colg_names = {"Name":    ['KJSIEIT', 'TSCOE', 'DBIT', 'RAIT', 'VESIT'],
             "Location": ['Sion',    'Bandra','Kurla','Nerul','Chembur'],
             "Cut-off":  ['60%',     '65%',      np.nan,    '84%', '90%']}

# %%
print(colg_names.keys())
# Out:
# dict_keys(['Name', 'Location', 'Cut-off'])

# %%
print(colg_names.values())
# Out:
# dict_values([['KJSIEIT', 'TSCOE', 'DBIT', 'RAIT', 'VESIT'], ['Sion', 'Bandra', 'Kurla', 'Nerul', 'Chembur'], ['60%', '65%', nan, '84%', '90%']])

# %%
colg_df = pd.DataFrame(colg_names)

# %%
colg_df.head()
# Out:
#       Name Location Cut-off
# 0  KJSIEIT     Sion     60%
# 1    TSCOE   Bandra     65%
# 2     DBIT    Kurla     NaN
# 3     RAIT    Nerul     84%
# 4    VESIT  Chembur     90%

# %%
menu_data = pd.read_csv("menu.csv")

# %%
menu_data.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
menu_data.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
menu_data_melted = pd.melt(menu_data, 
                           id_vars = ["Category", "Item", "Serving Size", "Calories"],
                          var_name = "Stats")

# %%
menu_data_melted.head(10)
# Out:
#     Category                                               Item  \
# 0  Breakfast                                       Egg McMuffin
# 1  Breakfast                                  Egg White Delight
# 2  Breakfast                                   Sausage McMuffin
# 3  Breakfast                          Sausage McMuffin with Egg
# 4  Breakfast                   Sausage McMuffin with Egg Whites
# 5  Breakfast                               Steak & Egg McMuffin
# 6  Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7  Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8  Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9  Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
#
#      Serving Size  Calories              Stats  value
# 0  4.8 oz (136 g)       300  Calories from Fat  120.0
# 1  4.8 oz (135 g)       250  Calories from Fat   70.0
# 2  3.9 oz (111 g)       370  Calories from Fat  200.0
# ...

# %%
print(menu_data.shape)
print(menu_data_melted.shape)
# Out:
# (260, 24)
# (5200, 6)

# %%
menu_data_melted.Stats.unique()
# Out:
# array(['Calories from Fat', 'Total Fat', 'Total Fat (% Daily Value)',
#        'Saturated Fat', 'Saturated Fat (% Daily Value)', 'Trans Fat',
#        'Cholesterol', 'Cholesterol (% Daily Value)', 'Sodium',
#        'Sodium (% Daily Value)', 'Carbohydrates',
#        'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'], dtype=object)

# %%
menu_drop = menu_data.drop(["Total Fat (% Daily Value)",
                                   'Saturated Fat (% Daily Value)',
                                   'Cholesterol (% Daily Value)',
                                    'Sodium (% Daily Value)',
                                   'Carbohydrates (% Daily Value)',
                                   'Dietary Fiber (% Daily Value)',
                                   'Vitamin A (% Daily Value)', 
                                   'Vitamin C (% Daily Value)',
                                   'Calcium (% Daily Value)', 
                                   'Iron (% Daily Value)'
                                  ], axis=1)

# %%
menu_drop.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Saturated Fat  Trans Fat  Cholesterol  \
# 0                120       13.0            5.0        0.0          260
# 1                 70        8.0            3.0        0.0           25
# 2                200       23.0            8.0        0.0           45
# 3                250       28.0           10.0        0.0          285
# 4                210       23.0            8.0        0.0           50
#
#    Sodium  Carbohydrates  Dietary Fiber  Sugars  Protein
# ...

# %%
menu_drop.Category.unique()
# Out:
# array(['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads',
#        'Snacks & Sides', 'Desserts', 'Beverages', 'Coffee & Tea',
#        'Smoothies & Shakes'], dtype=object)

# %%
menu_drop.nunique()
# Out:
# Category               9
# Item                 260
# Serving Size         107
# Calories              78
# Calories from Fat     48
# Total Fat             52
# Saturated Fat         26
# Trans Fat              5
# Cholesterol           35
# Sodium               111
# Carbohydrates         84
# Dietary Fiber          8
# Sugars                83
# Protein               42
# dtype: int64

# %%
menu_drop["Dietary Fiber"].unique()
# Out:
# array([4, 2, 3, 6, 7, 1, 5, 0], dtype=int64)

# %% [markdown]
# # New Example

# %%
# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}
 
df = pd.DataFrame(dict)
df.head()
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
# filling missing value using fillna()  
df.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %%
dict2 = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}
 
df = pd.DataFrame(dict2)

# %%
df.head()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
df.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0
